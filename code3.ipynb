# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df =pd.read_csv('./user_sleep_2020.csv')
df1 = pd.read_csv('./user_survey_2020.csv')

# %%
df.corr()
# Out:
#                                    startDt     endDt  lastUpdate  \
# startDt                           1.000000  0.999894    0.999850
# endDt                             0.999894  1.000000    0.999945
# lastUpdate                        0.999850  0.999945    1.000000
# wakeupduration                    0.032959  0.037804    0.037307
# lightsleepduration               -0.035981 -0.025495   -0.025801
# deepsleepduration                -0.003210  0.004209    0.003627
# wakeupcount                      -0.068281 -0.065156   -0.066402
# durationtosleep                   0.081122  0.082753    0.082803
# remsleepduration                 -0.105528 -0.096581   -0.096811
# durationtowakeup                  0.024862  0.026011    0.025844
# hr_average                        0.108073  0.106566    0.106154
# hr_min                            0.050797  0.046992    0.046930
# hr_max                            0.102883  0.106122    0.105711
# ...

# %%
df
# Out:
#      userId    timezone        date     startDt       endDt  lastUpdate  \
# 0    user24  Asia/Seoul  2020-08-30  1598708760  1598740860  1598748252
# 1    user24  Asia/Seoul  2020-08-31  1598800140  1598825940  1598833333
# 2    user24  Asia/Seoul  2020-09-01  1598885940  1598908800  1598916190
# 3    user24  Asia/Seoul  2020-09-02  1598979420  1598999580  1599006969
# 4    user24  Asia/Seoul  2020-09-03  1599060780  1599085980  1599093370
# ..      ...         ...         ...         ...         ...         ...
# 610  user06  Asia/Seoul  2020-10-05  1601831040  1601861820  1601862001
# 611  user06  Asia/Seoul  2020-10-06  1601923560  1601951220  1601951380
# 612  user06  Asia/Seoul  2020-10-07  1602001320  1602023760  1602031150
# 613  user06  Asia/Seoul  2020-10-08  1602091020  1602110280  1602117673
# 614  user06  Asia/Seoul  2020-10-09  1602183900  1602220140  1602227533
#
#      wakeupduration  lightsleepduration  deepsleepduration  wakeupcount  ...  \
# ...

# %%
df[df['userId'] == 'user03']['sleep_score'].sort_values()
# Out:
# 238    20
# 239    20
# 243    20
# 237    52
# 251    56
# 249    67
# 246    68
# 241    75
# 250    75
# 245    77
# 248    81
# 244    84
# 236    85
# 247    85
# 242    86
# 240    89
# Name: sleep_score, dtype: int64

# %%
sns.distplot(df[df['userId'] == 'user03']['sleep_score'], bins=100, kde=False)
# Out:
# c:\Users\jhm21\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sleep_score'>

# %%
for i in range():
    df1.iloc[1]
# Out:
# userId                    user24
# date                  2020-08-29
# amPm                          pm
# startInput      2020-08-29 21:23
# endInput        2020-08-29 21:23
# sleep                        NaN
# sleepProblem                 NaN
# dream                        NaN
# amCondition                  NaN
# amEmotion                    NaN
# pmEmotion                    4.0
# pmStress                     4.0
# pmFatigue                    2.0
# caffeine                     NaN
# cAmount(ml)                  NaN
# alcohol                      NaN
# aAmount(ml)                  NaN
# Name: 1, dtype: object
