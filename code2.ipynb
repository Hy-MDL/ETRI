# %%
import folium
import time
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('./total.csv')
df
# Out:
#        Unnamed: 0                      ts            action  actionOption  \
# 0               0  2020_08_29_05_20_00_PM              work           212
# 1               1  2020_08_29_05_21_00_PM              work           212
# 2               2  2020_08_29_05_22_00_PM              work           212
# 3               3  2020_08_29_05_23_00_PM              work           212
# 4               4  2020_08_29_05_24_00_PM              work           212
# ...           ...                     ...               ...           ...
# 21097       21097  2020_09_27_11_33_00_PM  recreation_media           722
# 21098       21098  2020_09_27_11_34_00_PM  recreation_media           722
# 21099       21099  2020_09_27_11_35_00_PM  recreation_media           722
# 21100       21100  2020_09_27_11_49_00_PM  recreation_media           722
# 21101       21101  2020_09_27_11_54_00_PM  recreation_media           722
#
#       actionSub  actionSubOption  condition  conditionSub1Option  \
# 0           NaN              NaN  WITH_MANY                  5.0
# 1           NaN              NaN  WITH_MANY                  5.0
# 2           NaN              NaN  WITH_MANY                  5.0
# 3           NaN              NaN  WITH_MANY                  5.0
# 4           NaN              NaN  WITH_MANY                  5.0
# ...         ...              ...        ...                  ...
# 21097       NaN              NaN   WITH_ONE                  2.0
# 21098       NaN              NaN   WITH_ONE                  2.0
# 21099       NaN              NaN   WITH_ONE                  2.0
# 21100       NaN              NaN   WITH_ONE                  2.0
# 21101       NaN              NaN   WITH_ONE                  2.0
#
#        conditionSub2Option         place  ...  rr_average  rr_min  rr_max  \
# 0                      2.0  other_indoor  ...         NaN     NaN     NaN
# 1                      2.0  other_indoor  ...         NaN     NaN     NaN
# 2                      2.0  other_indoor  ...         NaN     NaN     NaN
# 3                      2.0  other_indoor  ...         NaN     NaN     NaN
# 4                      2.0  other_indoor  ...         NaN     NaN     NaN
# ...                    ...           ...  ...         ...     ...     ...
# 21097                  2.0          home  ...         NaN     NaN     NaN
# 21098                  2.0          home  ...         NaN     NaN     NaN
# 21099                  2.0          home  ...         NaN     NaN     NaN
# 21100                  2.0          home  ...         NaN     NaN     NaN
# 21101                  2.0          home  ...         NaN     NaN     NaN
#
#        breathing_disturbances_intensity  snoring  snoringepisodecount  \
# 0                                   NaN      NaN                  NaN
# 1                                   NaN      NaN                  NaN
# 2                                   NaN      NaN                  NaN
# 3                                   NaN      NaN                  NaN
# 4                                   NaN      NaN                  NaN
# ...                                 ...      ...                  ...
# 21097                               NaN      NaN                  NaN
# 21098                               NaN      NaN                  NaN
# 21099                               NaN      NaN                  NaN
# 21100                               NaN      NaN                  NaN
# 21101                               NaN      NaN                  NaN
#
#        sleep_score  snoring.1  snoringepisodecount.1  sleep_score.1
# 0              NaN        NaN                    NaN            NaN
# 1              NaN        NaN                    NaN            NaN
# 2              NaN        NaN                    NaN            NaN
# 3              NaN        NaN                    NaN            NaN
# 4              NaN        NaN                    NaN            NaN
# ...            ...        ...                    ...            ...
# 21097          NaN        NaN                    NaN            NaN
# 21098          NaN        NaN                    NaN            NaN
# 21099          NaN        NaN                    NaN            NaN
# 21100          NaN        NaN                    NaN            NaN
# 21101          NaN        NaN                    NaN            NaN
#
# [21102 rows x 57 columns]

# %%
times = df.index.tolist()
center = df[['mgps_lat_mean','mgps_lon_mean']].iloc[1].tolist()

# %%
x_y= pd.concat([df['mgps_lat_mean'],df['mgps_lon_mean']],axis=1)
x_y_ts= pd.concat([df['ts'],df['mgps_lat_mean'],df['mgps_lon_mean']],axis=1)

x_y_n=x_y.dropna()

# %%
df.loc[df['emotionPositive']>=6]['action']
# Out:
# 25            travel
# 26            travel
# 27            travel
# 28            travel
# 29            travel
#             ...
# 20939    outdoor_act
# 20940    outdoor_act
# 20941    outdoor_act
# 20942    outdoor_act
# 20943    outdoor_act
# Name: action, Length: 10775, dtype: object

# %%
x_y_ts=x_y_ts.dropna()

# %%
x_y_ts['ts'].iloc[-1][8:10]
# Out:
# '27'

# %%
df[[ 'condition', 'conditionSub1Option','conditionSub2Option', 'place', 'emotionPositive', 'emotionTension',]].corr()
# Out:
#                      conditionSub1Option  conditionSub2Option  \
# conditionSub1Option             1.000000            -0.533181
# conditionSub2Option            -0.533181             1.000000
# emotionPositive                -0.258590             0.536403
# emotionTension                  0.732289            -0.414390
#
#                      emotionPositive  emotionTension
# conditionSub1Option        -0.258590        0.732289
# conditionSub2Option         0.536403       -0.414390
# emotionPositive             1.000000       -0.000828
# emotionTension             -0.000828        1.000000

# %%
df[df['place']=='other_indoor']
# Out:
#        Unnamed: 0                      ts       action  actionOption  \
# 0               0  2020_08_29_05_20_00_PM         work           212
# 1               1  2020_08_29_05_21_00_PM         work           212
# 2               2  2020_08_29_05_22_00_PM         work           212
# 3               3  2020_08_29_05_23_00_PM         work           212
# 4               4  2020_08_29_05_24_00_PM         work           212
# ...           ...                     ...          ...           ...
# 18539       18539  2020_09_24_09_45_00_PM  outdoor_act           756
# 18540       18540  2020_09_24_09_46_00_PM  outdoor_act           756
# 18541       18541  2020_09_24_09_47_00_PM  outdoor_act           756
# 18542       18542  2020_09_24_09_48_00_PM  outdoor_act           756
# 18543       18543  2020_09_24_09_49_00_PM  outdoor_act           756
#
#       actionSub  actionSubOption  condition  conditionSub1Option  \
# 0           NaN              NaN  WITH_MANY                  5.0
# 1           NaN              NaN  WITH_MANY                  5.0
# 2           NaN              NaN  WITH_MANY                  5.0
# 3           NaN              NaN  WITH_MANY                  5.0
# 4           NaN              NaN  WITH_MANY                  5.0
# ...         ...              ...        ...                  ...
# 18539       NaN              NaN  WITH_MANY                  5.0
# 18540       NaN              NaN  WITH_MANY                  5.0
# 18541       NaN              NaN  WITH_MANY                  5.0
# 18542       NaN              NaN  WITH_MANY                  5.0
# 18543       NaN              NaN  WITH_MANY                  5.0
#
#        conditionSub2Option         place  ...  rr_average  rr_min  rr_max  \
# 0                      2.0  other_indoor  ...         NaN     NaN     NaN
# 1                      2.0  other_indoor  ...         NaN     NaN     NaN
# 2                      2.0  other_indoor  ...         NaN     NaN     NaN
# 3                      2.0  other_indoor  ...         NaN     NaN     NaN
# 4                      2.0  other_indoor  ...         NaN     NaN     NaN
# ...                    ...           ...  ...         ...     ...     ...
# 18539                  1.0  other_indoor  ...         NaN     NaN     NaN
# 18540                  1.0  other_indoor  ...         NaN     NaN     NaN
# 18541                  1.0  other_indoor  ...         NaN     NaN     NaN
# 18542                  1.0  other_indoor  ...         NaN     NaN     NaN
# 18543                  1.0  other_indoor  ...         NaN     NaN     NaN
#
#        breathing_disturbances_intensity  snoring  snoringepisodecount  \
# 0                                   NaN      NaN                  NaN
# 1                                   NaN      NaN                  NaN
# 2                                   NaN      NaN                  NaN
# 3                                   NaN      NaN                  NaN
# 4                                   NaN      NaN                  NaN
# ...                                 ...      ...                  ...
# 18539                               NaN      NaN                  NaN
# 18540                               NaN      NaN                  NaN
# 18541                               NaN      NaN                  NaN
# 18542                               NaN      NaN                  NaN
# 18543                               NaN      NaN                  NaN
#
#        sleep_score  snoring.1  snoringepisodecount.1  sleep_score.1
# 0              NaN        NaN                    NaN            NaN
# 1              NaN        NaN                    NaN            NaN
# 2              NaN        NaN                    NaN            NaN
# 3              NaN        NaN                    NaN            NaN
# 4              NaN        NaN                    NaN            NaN
# ...            ...        ...                    ...            ...
# 18539          NaN        NaN                    NaN            NaN
# 18540          NaN        NaN                    NaN            NaN
# 18541          NaN        NaN                    NaN            NaN
# 18542          NaN        NaN                    NaN            NaN
# 18543          NaN        NaN                    NaN            NaN
#
# [2153 rows x 57 columns]

# %%
x_y_n.folium()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18268\95315434.py in <module>
# ----> 1 x_y_n.folium()
#
# c:\Users\jhm21\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'folium'
